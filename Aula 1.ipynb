# %% [markdown]
# <a href="https://colab.research.google.com/github/Chel2815/2ema-front-Iot-ReactJs-Vite-Chel281/blob/main/Aula%201.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World!")
# Out:
# Hello World!
